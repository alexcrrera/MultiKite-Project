# %% [markdown]
# # **MULTIKITE PROJECT LOG**

# %% [markdown]
# Here I'll write useful stuff for the project

# %% [markdown]
# ## Notation:

# %% [markdown]
# ## REYNOLDS NUMBER

# %% [markdown]
# $$Re_y = \frac{\rho \cdot V \cdot c}{\mu}= \frac{\rho \cdot \omega(R + y) \cdot c}{\mu}$$

# %% [markdown]
# $$Re_{max} = \frac{\rho \cdot \omega(R + \frac{b}{2}) \cdot c}{\mu}$$

# %% [markdown]
# $$\approx$$

# %% [markdown]
# Let $R$ be the horizontal distance from the rotor axis to the center of the wing (the tether attachment point). Let $b$ be the span (length) of the wing

# %% [markdown]
# > Local Radius: $r(y) = R + y$                                                                          Local Velocity:
# $V(y) = \omega \cdot r(y) = \omega (R + y)$ where $\omega$ is the angular velocity of the rotor.

# %% [markdown]
# $$L_i = \int_{-\frac{b}{2}}^{\frac{b}{2}} \frac{1}{2} \rho C_L c \left[ \omega (R + y) \right]^2 dy$$

# %% [markdown]
# $$L_i = \frac{1}{2} \rho S C_L (\omega R)^2 \left[ 1 + \frac{1}{12} \left( \frac{b}{R} \right)^2 \right]$$

# %% [markdown]
# $$ C_L = f(AOA)=f(\alpha)$$

# %% [markdown]
# Comments on high AOA at take off:

# %% [markdown]
# Seems like predicting the $CL = f(AOA)$ at extreme angles will be extremely complex, time-consuming and unrelieable. Stalling the wing makes the dynamic excessively hard to model.

# %% [markdown]
# # Concept 1): Slow release from center
